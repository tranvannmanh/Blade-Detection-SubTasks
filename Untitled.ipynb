# %%
from PIL import Image
from scipy.ndimage import zoom
import matplotlib.pyplot as plt

# %%
img = Image.open('./engine.png').convert('L')
img
# Out:
# <PIL.Image.Image image mode=L size=300x227 at 0x2303D381FC0>

# %%
zoom_in = zoom(img, 0.5)
plt.imshow(zoom_in, cmap='gray')
