# %%
import numpy as np
import pytesseract as tes
from matplotlib.pyplot import imread
from PIL import Image
import matplotlib.pyplot as plt
import cv2

# custome_config = r'C:/Program Files/Tesseract-OCR/tesseract.exe'
custom_config = r'--oem 3 --psm 6'

# %%
the_roi = Image.open('./the_roi.png')
# plt.imshow(the_roi, cmap='gray')
the_roi
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=348x390 at 0x1DBC271F580>

# %%
tes.image_to_string(the_roi, config=custom_config)
# Out:
# 'THE KEY\nTO SUCCESS\nRS)\nTO;FOCUS\nON:GOALS,\nNOT OBSTACLES:\n'
